# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 1, 100)

# %%
def expFunc(a):
    return a * a

# %%
plt.plot(x, expFunc(x))
plt.xlabel("Time [milliseconds]")
plt.ylabel("Awesomeness")

plt.savefig("exp_plot.pdf")
plt.show()
