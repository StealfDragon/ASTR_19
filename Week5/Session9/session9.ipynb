# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.uniform(0, 1, 1000)

# %%
plt.hist(x, 100)
plt.xlabel("Random numbers (Uniform between 0 and 1)")
plt.ylabel("Frequency")

plt.savefig("0to1Histogram.pdf")
plt.show()
