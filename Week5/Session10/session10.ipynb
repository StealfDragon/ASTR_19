# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.pareto(500, size = 1000)

# %%
plt.hist(x, 100)
plt.xlabel("Random values (Pareto distribution)")
plt.ylabel("Frequency")

plt.savefig("ParetoDistrHistogram.pdf")
plt.show()
